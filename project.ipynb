# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\GOWRI SANKAR\YEARLY_2023_CAAQMS_FINAL_UPLOAD_merged 2.csv",na_values='-')

# %%
data
# Out:
#           CO     Ozone      NO2       SO2     PM2.5      PM10   AQI
# 0        NaN       NaN      NaN       NaN       NaN       NaN   NaN
# 1    0.75000  18.07000   6.7600   9.26000  43.96000  69.54000  73.0
# 2    0.74000  17.64000   6.6200   9.87000  44.08000  69.75000  73.0
# 3    1.03000  16.15000   6.7400   9.87000  39.21000  62.83000  65.0
# 4    1.17000  17.59000   7.1200  10.81000  41.75000  66.50000  70.0
# ..       ...       ...      ...       ...       ...       ...   ...
# 762  0.58008  27.21238  12.3866  14.20219  25.54167  56.20833  56.0
# 763  0.45510  22.82584  14.6582  14.38560  16.50000  34.66667  35.0
# 764  0.45719  27.07407  12.7963  13.44474  16.91667  35.45833  35.0
# 765  0.53634  26.34239  12.6594  14.42967  19.16667  40.91667  41.0
# 766  0.58789  18.22695  16.0060  13.16010  17.70833  37.50000  38.0
#
# [767 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# CO       47
# Ozone    40
# NO2      40
# SO2      40
# PM2.5    45
# PM10     44
# AQI      43
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# CO       0
# Ozone    0
# NO2      0
# SO2      0
# PM2.5    0
# PM10     0
# AQI      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X=data[['CO','Ozone','NO2',	'SO2','PM2.5','PM10']]
y=data['AQI']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (572, 6)

# %%
X_test.shape
# Out:
# (143, 6)

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=3)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6546786912231948

# %%
from sklearn.metrics import mean_squared_error

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 14.487515725206716

# %%
from sklearn.tree import DecisionTreeRegressor
model1=DecisionTreeRegressor()

# %%
model1.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model1.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6346133762866069

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 14.902480199078141

# %%
from sklearn.ensemble import RandomForestRegressor
model3=RandomForestRegressor()

# %%
model3.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model3.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8165431683939429

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 10.559641536085842

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.777637270768937

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 11.625542526929166

# %%
import pickle
file=open("finalmodel.pkl","wb")
pickle.dump(model3,file)
file.close()
